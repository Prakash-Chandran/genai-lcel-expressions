# %%
# Install Libraries
# !pip install -U langchain-google-genai langchain
# Out:
# Requirement already satisfied: langchain-google-genai in /usr/local/lib/python3.12/dist-packages (4.3.2)
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.3.14)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (2.11.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (1.5.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (2.13.4)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.2.9)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.49.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.10.2)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (49.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.1.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.0)

# %%
import os

os.environ["GOOGLE_API_KEY"] = "YOUR API KEY"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableMap

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    temperature=0.3
)

# %%
career_prompt = ChatPromptTemplate.from_template(
"""
You are a professional career counselor.

Student Skills:
{skills}

Career Interest:
{interest}

Suggest:
1. Best Career Path
2. Required Skills
3. Learning Resources
4. Career Tips

Keep the explanation simple.
"""
)

parser = StrOutputParser()

career_chain = career_prompt | model | parser

response = career_chain.invoke(
    {
        "skills": "Python, Machine Learning, SQL",
        "interest": "Artificial Intelligence Engineer"
    }
)

print(response)
# Out:
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py:3120: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Hello! As your career counselor, I am excited to help you achieve your goal. You already have a **fantastic foundation** with Python, Machine Learning, and SQL. These are the core building blocks for a career in Artificial Intelligence.
#
# Here is your tailored roadmap to becoming a successful **Artificial Intelligence (AI) Engineer**.
#
# ---
#
# ### 1. Best Career Path
#
# Since you already know Python, ML, and SQL, your best path looks like this:
#
# 1. **Junior ML/AI Developer:** Start by building simple AI tools and expanding your core skills.
# 2. **AI Engineer (Target Role):** Design, build, and deploy smart AI systems (like chatbots, image recognition, or predictive engines) into real-world applications.
# 3. **Senior AI Engineer / AI Architect:** Lead complex AI projects, design AI systems for big companies, and manage AI deployment pipelines.
#
# ---
#
# ### 2. Required Skills (To bridge the gap)
#
# To move from basic Machine Learning to a full **AI Engineer**, you need to add these skills to your toolkit:
#
# * **Deep Learning Frameworks:** Learn **PyTorch** or **TensorFlow** (PyTorch is currently the industry favorite).
# * **Generative AI & LLMs:** Learn how Large Language Models work, how to use APIs (like OpenAI), and concepts like **RAG** (Retrieval-Augmented Generation) and **Prompt Engineering**.
# * **Model Deployment (MLOps):** Learn how to turn your AI models into usable apps using **FastAPI**, **Docker**, and Cloud platforms (like AWS or Google Cloud).
# * **Version Control:** **Git & GitHub** to manage your code and show off your projects to recruiters.
#
# ---
#
# ### 3. Learning Resources
#
# Here are some of the best, student-friendly resources to learn these skills:
#
# * **Deep Learning & GenAI:**
#   * *DeepLearning.AI (Coursera):* "Deep Learning Specialization" by Andrew Ng (The gold standard).
#   * *Fast.ai:* "Practical Deep Learning for Coders" (Free, hands-on, and simple).
# * **Hands-on Practice:**
#   * *Kaggle:* Practice on real-world datasets and join beginner competitions.
# * **Books:**
#   * *"Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow"* by Aurélien Géron.
#
# ---
#
# ### 4. Career Tips for Success
#
# 1. **Build a Portfolio, Not Just a Resume:** Recruiters care about what you can build. Create 2–3 end-to-end projects (e.g., an AI-powered document reader or a custom smart chatbot) and host them on GitHub.
# 2. **Focus on "Generative AI":** The industry currently has a massive demand for developers who can integrate LLMs (like GPT-4) into business products.
# 3. **Learn MLOps Early:** Knowing how to write an AI model is good; knowing how to *put it on a website or cloud app* will instantly set you apart from other applicants.
# 4. **Network on LinkedIn:** Share your learning journey, post about your mini-projects, and connect with working AI Engineers.
#
# You are off to a great start. Focus on building projects step-by-step, and you will get there! Good luck!

# %%
context_prompt = ChatPromptTemplate.from_template(
"""
Context:
{context}

Question:
{question}

Answer:
"""
)

inputs = RunnableMap({
    "context": lambda x:
        "Artificial Intelligence Engineers develop intelligent systems using Machine Learning, Deep Learning, Python, TensorFlow, and Data Science.",
    "question": lambda x: x["question"]
})

context_chain = inputs | context_prompt | model | parser

response = context_chain.invoke(
    {
        "question": "Which programming languages should I learn for becoming an AI Engineer?"
    }
)

print(response)
# Out:
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py:3120: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Based on the provided context, you should learn **Python**.
